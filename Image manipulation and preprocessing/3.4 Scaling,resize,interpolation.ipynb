# %% [markdown]
# ## Scaling, re-sizing and interpolations
#
# Re-sizing is very easy using the cv2.resize function, it's arguments are:
#
# cv2.resize(image, dsize(output image size), x scale, y scale, interpolation)

# %% [markdown]
# * INTER_NEAREST – Fastest
# * INTER_LINEAR – Good for zooming
# * INTER_AREA – Good for shrinking or down sampling INTER_NEAREST method.
# * INTER_CUBIC – Better
# * INTER_LANCZOS4 – Best

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from google.colab import drive
drive.mount('/content/drive')
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
img=cv2.imread("/content/drive/Shareddrives/mayur/computer vision/images/input.jpg")

# Let's make our image 3/4 of it's original size
img_scaled=cv2.resize(img,None,fx=0.75,fy=0.75)
cv2_imshow(img_scaled)
cv2.waitKey()

# Let's double the size of our image
image_scaled=cv2.resize(img,None,fx=2,fy=2,interpolation=cv2.INTER_CUBIC)
cv2_imshow(img_scaled)
cv2.waitKey()

# Let's skew the re-sizing by setting exact dimensions
img_scale=cv2.resize(img,(900,400),interpolation=cv2.INTER_AREA)
cv2_imshow(img_scaled)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
