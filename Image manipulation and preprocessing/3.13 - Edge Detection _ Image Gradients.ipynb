# %% [markdown]
# ## Edge Detection & Image Gradients

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from google.colab import drive
drive.mount('/content/drive')
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
image=cv2.imread('/content/drive/Shareddrives/mayur/computer vision/images/input.jpg',0)
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44E0592250>
# -1

# %%
sobel_x=cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
sobel_y=cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)

cv2_imshow(sobel_x)
cv2.waitKey(0)
cv2_imshow(sobel_y)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44E1EA0490>
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44E1DF4D10>
# -1

# %%
sobel_or=cv2.bitwise_or(sobel_x,sobel_y)
cv2_imshow(sobel_or)
# Out:
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44F0D9A8D0>

# %%
laplace=cv2.Laplacian(image,cv2.CV_64F)
cv2_imshow(laplace)
# Out:
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44E05AF610>

# %%
##  Then, we need to provide two values: threshold1 and threshold2. Any gradient value larger than threshold2
# is considered to be an edge. Any value below threshold1 is considered not to be an edge. 
#Values in between threshold1 and threshold2 are either classiﬁed as edges or non-edges based on how their 
#intensities are “connected”. In this case, any gradient values below 60 are considered non-edges
#whereas any values above 120 are considered edges.


# Canny Edge Detection uses gradient values as thresholds
# The first threshold gradient
canny = cv2.Canny(image, 50, 120)
cv2_imshow(canny)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1245x830 at 0x7F44E04D66D0>
