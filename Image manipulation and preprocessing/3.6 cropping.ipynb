# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from google.colab import drive
drive.mount('/content/drive')
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
image=cv2.imread("/content/drive/Shareddrives/mayur/computer vision/images/input.jpg")

height,width=image.shape[:2]


start_row,start_col=int(height*0.25),int(width*0.25)

end_row,end_col=int(height*0.75),int(width*0.75)

crop_img=image[start_row:end_row,start_col:end_col]


cv2_imshow(image)
cv2.waitKey(0) 
cv2_imshow( crop_img) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1245x830 at 0x7F34D86B1E10>
# <PIL.Image.Image image mode=RGB size=622x415 at 0x7F34D854F790>
